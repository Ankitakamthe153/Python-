# %%
# Series: It a one dimensional array like coloumn data
color=['Red','Green','Blue']
series_color=pd.Series(color)
print(series_color)
# Out:
# 0      Red
# 1    Green
# 2     Blue
# dtype: object

# %%
record={
    'name':['ankita','om','dolly'],
    'age':[21,15,20],
    'color':['red','green','yellow']
}
data=pd.DataFrame(record)
print(data)
# Out:
#      name  age   color
# 0  ankita   21     red
# 1      om   15   green
# 2   dolly   20  yellow

# %%
import pandas as pd
df=pd.read_csv("sale.csv")
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#         Order Date                      Purchase Address
# 0   4/19/2019 8:46          917 1st St, Dallas, TX 75001
# 1              NaN                                   NaN
# 2   4/7/2019 22:30     682 Chestnut St, Boston, MA 02215
# 3  4/12/2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  4/12/2019 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
import pandas as pd
df=pd.read_csv("sale.csv")
df.tail()
# Out:
#        Order ID                 Product Quantity Ordered Price Each  \
# 186845   259353  AAA Batteries (4-pack)                3       2.99
# 186846   259354                  iPhone                1        700
# 186847   259355                  iPhone                1        700
# 186848   259356  34in Ultrawide Monitor                1     379.99
# 186849   259357    USB-C Charging Cable                1      11.95
#
#              Order Date                         Purchase Address
# 186845  9/17/2019 20:56   840 Highland St, Los Angeles, CA 90001
# 186846   9/1/2019 16:00  216 Dogwood St, San Francisco, CA 94016
# 186847   9/23/2019 7:39     220 12th St, San Francisco, CA 94016
# 186848  9/19/2019 17:30   511 Forest St, San Francisco, CA 94016
# 186849   9/30/2019 0:18   250 Meadow St, San Francisco, CA 94016

# %%
import pandas as pd
df=pd.read_csv("sale.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186850 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoint=np.array([0,3,6])
ypoint=np.array([0,100,200])

plt.plot(xpoint,ypoint,'o:r', ms=20, mec='blue', mfc='yellow')
plt.xlabel("xpoint",color="green")
plt.ylabel("ypoint",color="green")
plt.show()

# %% [markdown]
# # sales analysis case study

# %%
import pandas as pd
df=pd.read_csv("sale.csv")
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#         Order Date                      Purchase Address
# 0   4/19/2019 8:46          917 1st St, Dallas, TX 75001
# 1              NaN                                   NaN
# 2   4/7/2019 22:30     682 Chestnut St, Boston, MA 02215
# 3  4/12/2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  4/12/2019 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
df.head(10)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
# 6   176562        USB-C Charging Cable                1      11.95
# 7   176563  Bose SoundSport Headphones                1      99.99
# 8   176564        USB-C Charging Cable                1      11.95
# 9   176565          Macbook Pro Laptop                1       1700
#
#         Order Date                        Purchase Address
# 0   4/19/2019 8:46            917 1st St, Dallas, TX 75001
# 1              NaN                                     NaN
# ...

# %%
df.tail()
# Out:
#        Order ID                 Product Quantity Ordered Price Each  \
# 186845   259353  AAA Batteries (4-pack)                3       2.99
# 186846   259354                  iPhone                1        700
# 186847   259355                  iPhone                1        700
# 186848   259356  34in Ultrawide Monitor                1     379.99
# 186849   259357    USB-C Charging Cable                1      11.95
#
#              Order Date                         Purchase Address
# 186845  9/17/2019 20:56   840 Highland St, Los Angeles, CA 90001
# 186846   9/1/2019 16:00  216 Dogwood St, San Francisco, CA 94016
# 186847   9/23/2019 7:39     220 12th St, San Francisco, CA 94016
# 186848  9/19/2019 17:30   511 Forest St, San Francisco, CA 94016
# 186849   9/30/2019 0:18   250 Meadow St, San Francisco, CA 94016

# %% [markdown]
# # agument with additional column

# %%
#add month
df['month']=df['Order Date'].str[0:2]
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#         Order Date                      Purchase Address month
# 0   4/19/2019 8:46          917 1st St, Dallas, TX 75001    4/
# 1              NaN                                   NaN   NaN
# 2   4/7/2019 22:30     682 Chestnut St, Boston, MA 02215    4/
# 3  4/12/2019 14:38  669 Spruce St, Los Angeles, CA 90001    4/
# 4  4/12/2019 14:38  669 Spruce St, Los Angeles, CA 90001    4/

# %% [markdown]
# # cleaning up the data

# %%
#find nan
na_df=df[df.isna().any(axis=1)]
na_df.head()

#dropna
clean_df=df.dropna(how='all')
clean_df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#         Order Date                      Purchase Address month
# 0   4/19/2019 8:46          917 1st St, Dallas, TX 75001    4/
# 2   4/7/2019 22:30     682 Chestnut St, Boston, MA 02215    4/
# 3  4/12/2019 14:38  669 Spruce St, Los Angeles, CA 90001    4/
# 4  4/12/2019 14:38  669 Spruce St, Los Angeles, CA 90001    4/
# 5   4/30/2019 9:27     333 8th St, Los Angeles, CA 90001    4/

# %%
#find or
or_df=clean_df[clean_df['Order Date'].str[0:2]=='or']
or_df.head()
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, Quantity Ordered, Price Each, Order Date, Purchase Address, month]
# Index: []

# %%
#not or
clean_df=clean_df[clean_df['Order Date'].str[0:2]!='or']
clean_df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#         Order Date                      Purchase Address month
# 0   4/19/2019 8:46          917 1st St, Dallas, TX 75001    4/
# 2   4/7/2019 22:30     682 Chestnut St, Boston, MA 02215    4/
# 3  4/12/2019 14:38  669 Spruce St, Los Angeles, CA 90001    4/
# 4  4/12/2019 14:38  669 Spruce St, Los Angeles, CA 90001    4/
# 5   4/30/2019 9:27     333 8th St, Los Angeles, CA 90001    4/

# %%
#convert into specific data tye
clean_df['Quantity Ordered']=pd.to_numeric(clean_df['Quantity Ordered'])
clean_df['Price Each']=pd.to_numeric(clean_df['Price Each'])
clean_df.head()

# %%
#multipy the Quantity and Price and stored in the sale
clean_df['sale']=clean_df['Quantity Ordered']*clean_df['Price Each']
clean_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     118     if result is None:
# --> 119         result = _evaluate_standard(op, op_str, a, b)
#     120
#
# ...

# %%
 #Question: What was the best month for sales and how much earned in that month
results=clean_df.groupby('month').sum()
results
# Out:
#                                                 Order ID  \
# month
# 1/     2971502978172978172979692983442990492991253003...
# 10     2593582593592593602593612593622593632593642593...
# 11     2787972787982787992788002788012788022788032788...
# 12     2956652956662956672956682956692956702956712956...
# 2/     1505021505031505041505051505061505071505081505...
# 3/     1505331505411508121517491520361532841535441538...
# 4/     1765581765591765601765601765611765621765631765...
# 5/     1769781775511777781777781790761790761791341800...
# 6/     2099212099222099232099242099252099262099272099...
# 7/     2229102229112229122229132229142229152229162229...
# 8/     2366702366712366722366732366742366752366762366...
# 9/     2388342392852406362410542423432428652436672449...
# Or     Order IDOrder IDOrder IDOrder IDOrder IDOrder ...
#
#                                                  Product  \
# month
# 1/     Lightning Charging CableiPhoneLightning Chargi...
# ...

# %%
import matplotlib.pyplot as plt
month=range(1,13)
plt.bar(month,results['sale'])
plt.xticks('month')
plt.xlabel("month")
plt.ylabel("sale")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sale'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-184b7d6ad2cf> in <module>
# ...

# %%
#which city having most sale
def get_city(address):
    return address.split(',')[1]
clean_df['city']=clean_df['Purchase Address'].apply(lambda  x:get_city(x))

def get_state(address):
    return address.split(',')[2]

clean_df['state']=clean_df['Purchased Address'].apply(lambda y:get_state(y))
clean_df()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-004d15dd880a> in <module>
#       2 def get_city(address):
#       3     return address.split(',')[1]
# ----> 4 clean_df['city']=clean_df['Purchase Address'].apply(lambda  x:get_city(x))
#       5
#       6 def get_state(address):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-38-004d15dd880a> in <lambda>(x)
#       2 def get_city(address):
#       3     return address.split(',')[1]
# ...

# %%
# Question 2: What was the best city for sales and how much earned in that city
result=clean_df.groupby('city').sum()
result

# %%
import matplotlib.pyplot as plt
cities=[city for city,df in clean_df.groupby('city')]
plt.bar(cities,results['sale'])
plt.xticks(cities,rotation='vertical',size=8)
plt.yticks(result['sale'])
plt.xlabel("cities")
plt.ylabel("sale")
plt.show()

# %%
# Question 3: What was the best Sate for sales and how much earned in that state
result=clean_df.groupby('state').sum()
result

# %%
import matplotlib.pyplot as plt
states=[state for state,df in clean_df.groupby('state')]
plt.bar(states,result['sale'])
plt.xticks(states,rotation='vertical',size=8)
plt.yticks(result['sale'])
plt.xlabel("state")
plt.ylabel('sale')
plt.show()

# %%
# What time should we display advertisement to maxmise likelyhood customer that buying product
clean_df['Order Date']=pd.to_datetime(clean_df['Order Date'])
clean_df['hour']=clean_df['Order Date'].dt.hour
clean_df['minute']=clean_df['Order Date'].dt.minute
clean_df.head()

# %%
result=clean_df.groupby('hour').count()
result

# %%
import pandas as pd
color=['red','blue','green']
scolor=pd.Series(color)
print(scolor)
# Out:
# 0      red
# 1     blue
# 2    green
# dtype: object

# %%
rec={
    'name':['ankita','vaishnavi','om'],
    'age':[67,98,90],
    'degree':['b.e.','b.sc','school']
}
record=pd.DataFrame(rec)
print(record)
# Out:
#         name  age  degree
# 0     ankita   67    b.e.
# 1  vaishnavi   98    b.sc
# 2         om   90  school

# %%
info={
    'name':['ankita','vaish','om'],
    'age':[56,78,98],
    'mobile no.':[876654,867554,790897867],
    'e-mail':['ankota56@gmail.com','vaish56@gmail.com','om67@gmail.com'],
    'qualification':['b.e.','b.sc.','school']
}
information=pd.DataFrame(info)
print(information)
# Out:
#      name  age  mobile no.              e-mail qualification
# 0  ankita   56      876654  ankota56@gmail.com          b.e.
# 1   vaish   78      867554   vaish56@gmail.com         b.sc.
# 2      om   98   790897867      om67@gmail.com        school

# %%
fruit=['apple','banana','grapes','kiwi','mango']
fruits=pd.Series(fruit)
print(fruits)
# Out:
# 0     apple
# 1    banana
# 2    grapes
# 3      kiwi
# 4     mango
# dtype: object

# %%
dc=pd.read_csv('sale.csv')
dc.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#         Order Date                      Purchase Address
# 0   4/19/2019 8:46          917 1st St, Dallas, TX 75001
# 1              NaN                                   NaN
# 2   4/7/2019 22:30     682 Chestnut St, Boston, MA 02215
# 3  4/12/2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  4/12/2019 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
dc.tail()
# Out:
#        Order ID                 Product Quantity Ordered Price Each  \
# 186845   259353  AAA Batteries (4-pack)                3       2.99
# 186846   259354                  iPhone                1        700
# 186847   259355                  iPhone                1        700
# 186848   259356  34in Ultrawide Monitor                1     379.99
# 186849   259357    USB-C Charging Cable                1      11.95
#
#              Order Date                         Purchase Address
# 186845  9/17/2019 20:56   840 Highland St, Los Angeles, CA 90001
# 186846   9/1/2019 16:00  216 Dogwood St, San Francisco, CA 94016
# 186847   9/23/2019 7:39     220 12th St, San Francisco, CA 94016
# 186848  9/19/2019 17:30   511 Forest St, San Francisco, CA 94016
# 186849   9/30/2019 0:18   250 Meadow St, San Francisco, CA 94016

# %%
dc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186850 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB

# %%
dc.tail(10)
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 186840   259349    AAA Batteries (4-pack)                1       2.99
# 186841   259350              Google Phone                1        600
# 186842   259350      USB-C Charging Cable                1      11.95
# 186843   259351  Apple Airpods Headphones                1        150
# 186844   259352      USB-C Charging Cable                1      11.95
# 186845   259353    AAA Batteries (4-pack)                3       2.99
# 186846   259354                    iPhone                1        700
# 186847   259355                    iPhone                1        700
# 186848   259356    34in Ultrawide Monitor                1     379.99
# 186849   259357      USB-C Charging Cable                1      11.95
#
#              Order Date                         Purchase Address
# 186840   9/1/2019 22:14           911 River St, Dallas, TX 75001
# 186841  9/30/2019 13:49    519 Maple St, San Francisco, CA 94016
# ...

# %%
dc.head(20)
# Out:
#    Order ID                     Product Quantity Ordered Price Each  \
# 0    176558        USB-C Charging Cable                2      11.95
# 1       NaN                         NaN              NaN        NaN
# 2    176559  Bose SoundSport Headphones                1      99.99
# 3    176560                Google Phone                1        600
# 4    176560            Wired Headphones                1      11.99
# 5    176561            Wired Headphones                1      11.99
# 6    176562        USB-C Charging Cable                1      11.95
# 7    176563  Bose SoundSport Headphones                1      99.99
# 8    176564        USB-C Charging Cable                1      11.95
# 9    176565          Macbook Pro Laptop                1       1700
# 10   176566            Wired Headphones                1      11.99
# 11   176567                Google Phone                1        600
# 12   176568    Lightning Charging Cable                1      14.95
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[0,3,6,8]
y=[0,100,200,300]
plt.plot(x,y,'D:b',ms=15,mec='red',mfc='green')
plt.xlabel("x-axis",color='pink')
plt.ylabel("y-axis",color='pink')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[4.5,6.7,8.9]
y=[100,150,200]
plt.plot(x,y,'s:r',ms=20,mec='red',mfc='yellow')
plt.xlabel("X",color='green')
plt.ylabel("y",color='green')
plt.show()

# %%
dc=pd.read_csv("sale.csv")
dc.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#         Order Date                      Purchase Address
# 0   4/19/2019 8:46          917 1st St, Dallas, TX 75001
# 1              NaN                                   NaN
# 2   4/7/2019 22:30     682 Chestnut St, Boston, MA 02215
# 3  4/12/2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  4/12/2019 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
dc.head(10)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
# 6   176562        USB-C Charging Cable                1      11.95
# 7   176563  Bose SoundSport Headphones                1      99.99
# 8   176564        USB-C Charging Cable                1      11.95
# 9   176565          Macbook Pro Laptop                1       1700
#
#         Order Date                        Purchase Address
# 0   4/19/2019 8:46            917 1st St, Dallas, TX 75001
# 1              NaN                                     NaN
# ...

# %%
dc.tail(10)
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 186840   259349    AAA Batteries (4-pack)                1       2.99
# 186841   259350              Google Phone                1        600
# 186842   259350      USB-C Charging Cable                1      11.95
# 186843   259351  Apple Airpods Headphones                1        150
# 186844   259352      USB-C Charging Cable                1      11.95
# 186845   259353    AAA Batteries (4-pack)                3       2.99
# 186846   259354                    iPhone                1        700
# 186847   259355                    iPhone                1        700
# 186848   259356    34in Ultrawide Monitor                1     379.99
# 186849   259357      USB-C Charging Cable                1      11.95
#
#              Order Date                         Purchase Address
# 186840   9/1/2019 22:14           911 River St, Dallas, TX 75001
# 186841  9/30/2019 13:49    519 Maple St, San Francisco, CA 94016
# ...

# %%
dc['day']=dc['Order Date'].str[0:1]
dc.head
# Out:
# <bound method NDFrame.head of        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#              Order Date                         Purchase Address  day
# ...

# %%
dc['month']=dc['Order Date'].str[0:1]
dc.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#         Order Date                      Purchase Address  day month
# 0   4/19/2019 8:46          917 1st St, Dallas, TX 75001    4     4
# 1              NaN                                   NaN  NaN   NaN
# 2   4/7/2019 22:30     682 Chestnut St, Boston, MA 02215    4     4
# 3  4/12/2019 14:38  669 Spruce St, Los Angeles, CA 90001    4     4
# 4  4/12/2019 14:38  669 Spruce St, Los Angeles, CA 90001    4     4
